# %% [markdown]
# Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data

# %%
df = pd.read_csv("data/tanzania.csv")
df["Country"] = "Tanzania"

# %% [markdown]
# Change Date format & Extract month

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")
df["Month"] = df["Date"].dt.month

# %% [markdown]
# Cleaning (replacing -999 with nan and dropping duplicates)

# %%
df.replace(-999, np.nan, inplace=True)

duplicates = df.duplicated().sum()
print("Duplicates:", duplicates)

df = df.drop_duplicates()
# Out:
# Duplicates: 0

# %% [markdown]
# the data has no duplicate values.

# %% [markdown]
# summary statistics

# %%
df.head(5)
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  27.56    29.52    26.22       3.30         7.24  80.97  4.68
# 1  2015    2  27.59    29.99    25.92       4.07         3.40  79.63  4.48
# 2  2015    3  27.47    29.29    26.25       3.04         7.17  80.02  4.91
# 3  2015    4  27.28    29.17    25.96       3.21        16.07  81.78  4.88
# 4  2015    5  26.68    27.83    25.84       1.99        18.83  82.99  4.17
#
#    WS2M_MAX      PS   QV2M   Country       Date  Month
# 0      6.01  100.52  18.61  Tanzania 2015-01-01      1
# 1      5.28  100.52  18.31  Tanzania 2015-01-02      1
# 2      5.99  100.56  18.30  Tanzania 2015-01-03      1
# 3      6.07  100.47  18.52  Tanzania 2015-01-04      1
# 4      5.98  100.43  18.16  Tanzania 2015-01-05      1

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX     T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.00000
# mean   2020.131451   180.121227    26.802422    29.163493    25.03813
# min    2015.000000     1.000000    22.680000    25.410000    20.03000
# 25%    2017.000000    86.000000    25.670000    28.090000    23.71000
# 50%    2020.000000   179.000000    26.990000    29.080000    25.37500
# 75%    2023.000000   272.000000    27.900000    30.170000    26.31000
# max    2026.000000   366.000000    29.970000    33.930000    28.01000
# std       3.248907   106.294767     1.325388     1.371155     1.53544
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean      4.125363     3.740256    77.128038     4.105370     5.189248
# min       0.940000     0.000000    60.060000     1.120000     1.550000
# 25%       3.330000     0.110000    73.167500     3.410000     4.377500
# 50%       4.220000     0.640000    76.585000     4.190000     5.250000
# 75%       4.940000     3.790000    81.100000     4.830000     5.980000
# max       7.590000   122.650000    91.100000     8.400000    11.740000
# std       1.102831     8.003947     5.070501     1.059803     1.215018
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean    100.801130    16.923683  2020-08-15 12:00:00     6.423564
# min     100.150000    11.380000  2015-01-01 00:00:00     1.000000
# 25%     100.570000    15.340000  2017-10-23 18:00:00     3.000000
# 50%     100.760000    17.220000  2020-08-15 12:00:00     6.000000
# 75%     101.040000    18.420000  2023-06-08 06:00:00     9.000000
# max     101.510000    21.510000  2026-03-31 00:00:00    12.000000
# std       0.284461     1.881741                  NaN     3.477046

# %% [markdown]
# The data contains of daily measurements of temperature, precipitation, humidity, and wind from year 2015 to 2026.This output shows the central tendencies and quartiles of the data. it shows thta for column. The mean for example in column T2M, 26°C was the average temperature. the range for temperature shows that it ranges fron 22°C to 29°C across all days. the percipitation column shows that rainfall ranges from 0 mm which were dry days to 122 mm which was heavy rain.
# the standard deviations shows moderate variability in all variables and we can also see that there were no missing values.

# %% [markdown]
# MIssing value

# %%
missing = df.isna().sum()
missing_percent = (missing / len(df)) * 100

missing_report = pd.DataFrame({
    "Missing Count": missing,
    "Percent": missing_percent
})

missing_report
# Out:
#              Missing Count  Percent
# YEAR                     0      0.0
# DOY                      0      0.0
# T2M                      0      0.0
# T2M_MAX                  0      0.0
# T2M_MIN                  0      0.0
# T2M_RANGE                0      0.0
# PRECTOTCORR              0      0.0
# RH2M                     0      0.0
# WS2M                     0      0.0
# WS2M_MAX                 0      0.0
# PS                       0      0.0
# QV2M                     0      0.0
# Country                  0      0.0
# Date                     0      0.0
# Month                    0      0.0

# %% [markdown]
# the output shows that there are no missing values so we can contine with the analysis and we dont need to do further process to fix this.

# %% [markdown]
# Handling outliers

# %%
from scipy.stats import zscore

cols = ["T2M","T2M_MAX","T2M_MIN","PRECTOTCORR","RH2M","WS2M","WS2M_MAX"]

z_scores = np.abs(df[cols].apply(zscore))

outliers = (z_scores > 3).sum()
print(outliers)
# Out:
# T2M             1
# T2M_MAX         2
# T2M_MIN         4
# PRECTOTCORR    81
# RH2M            2
# WS2M            8
# WS2M_MAX        4
# dtype: int64

# %% [markdown]
# Cap the outliers (it keeps all rows & it prevents extreme distortion by extreme values)

# %%
for col in cols:
    upper = df[col].mean() + 3*df[col].std()
    lower = df[col].mean() - 3*df[col].std()
    df[col] = np.clip(df[col], lower, upper)

# %% [markdown]
# export cleaned data

# %%
df.to_csv("data/tanzania_clean.csv", index=False)

# %% [markdown]
# time series analysis

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

monthly_temp.plot()
plt.title("Monthly Avg Temperature")
plt.show()

# %% [markdown]
# 4th month had the highest average temperature while the 7th month had the lowest amount of average temperature over the years.

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()

monthly_rain.plot(kind="bar")
plt.title("Monthly Rainfall")
plt.show()

# %% [markdown]
# the bar chart shows that 4th, 3rd, 5th, and 1st months had the highest average rainfall respectively while the 8th month had the lowest amount of average rainfall over the years.

# %% [markdown]
# the line chart shows that the temperature consistently is high in the beginig of the year and decreases over the months and then increases again throughout the years.

# %% [markdown]
# correlation analysis

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# this correlation analysis shows that the minimum daily temperature and atmospheric surface temperature are highly negatively correlated which means that when one increases the other decreases.
# the mean daily temperature is also negatively correlated with the atmospheric surface temperature. another strong correlation is between daily temperature range and relative humidity which are also negatively correlated.

# %% [markdown]
# scatter plot

# %%
sns.scatterplot(x="T2M", y="RH2M", data=df)
plt.show()

# %%
sns.scatterplot(x="T2M_RANGE", y="WS2M", data=df)
plt.show()

# %% [markdown]
# histogram

# %%
plt.figure()
plt.hist(df["PRECTOTCORR"].dropna(), bins=30)
plt.title("Distribution of PRECTOTCORR")
plt.xlabel("Precipitation")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# it is skewed to the right with most days experiencing low precipitation and a few extreme rainfall events. .so apply log scale to better visualize the distribution

# %%
plt.figure()
plt.hist(df["PRECTOTCORR"].dropna(), bins=30)
plt.yscale("log")
plt.title("Log-Scaled Distribution of PRECTOTCORR")
plt.xlabel("Precipitation")
plt.ylabel("Frequency (log scale)")
plt.show()

# %% [markdown]
# bubble chart

# %%
plt.scatter(df["T2M"], df["RH2M"], s=df["PRECTOTCORR"]*10)
plt.xlabel("T2M")
plt.ylabel("RH2M")
plt.show()
